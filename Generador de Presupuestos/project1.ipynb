# %% [markdown]
# # Project 001
#
# ## Mostrar información al usuario
#
# * print()

# %%
print("Python Practice Week")
print("Giovanni is a douchebag")

# %% [markdown]
# # Recibir información del usuario
#
# * input()

# %%
input("Escriba su clave: ")
input("Cuál es el mejor lenguaje de programación: ")

# %% [markdown]
# ## Almacenamiento de variables

# %%
project = "First project with Python"

# %%
print(project)

# %%
numero = 41

# %%
print(numero)

# %% [markdown]
# ## Mixin all learned concepts

# %%
proyecto = input("Escriba la descripción del proyecto: ")
horas_estimadas = input("Escriba las horas estimadas para el proyecto: ")
valor_hora= input("¿Cuál es el valor de la hora trabajada? ")
plazo_estimado = input("Escriba cuanto tiempo que va a tomar el proyecto: ")

# %%
print(proyecto)
print(horas_estimadas)
print(valor_hora)
print(plazo_estimado)

# %% [markdown]
# # Calculos con Python

# %%
print(10 + 2)
print(124 - 24)
print(13 * 2)
print(100 / 2)

# %% [markdown]
# ## Calculando el valor total del proyecto

# %%
valor_total = int(horas_estimadas) * int(valor_hora)

# %%
print(valor_total)

# %% [markdown]
# ## Generando archivos PDF del presupuesto
#
# * Crear archivo PDF
# * Definir el tipo de letra
# * Llenar los datos
# * Guardar el entregable

# %%
# %pip install fpdf

# %%
from fpdf import FPDF

# %%
pdf = FPDF()

pdf.add_page()
pdf.set_font("Arial")

pdf.image("Template.png", 0, 0)

pdf.text(115, 145, proyecto)
pdf.text(115, 160, horas_estimadas)
pdf.text(115, 175, valor_hora)
pdf.text(115, 190, plazo_estimado)
pdf.text(115, 205, str(valor_total))

pdf.output("Presupuesto.pdf")
