# %% [markdown]
# # Proyecto 2
#
# * Buscar datos del precio de las acciones
# * Hacer análisis solicitados por el gestor
#     * Cotización máxima
#     * Cotización mínima
#     * Valor medio
# * Enviar correo electrónico

# %% [markdown]
# ## Buscar datos del precio de las acciones

# %%
# %pip install yfinance
# %pip install matplotlib
# Out:
# Requirement already satisfied: yfinance in ./venv/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./venv/lib/python3.12/site-packages (from yfinance) (4.15.0)
# Requirement already satisfied: curl_cffi>=0.15 in ./venv/lib/python3.12/site-packages (from yfinance) (0.16.3)
# Requirement already satisfied: lxml>=4.9.0 in ./venv/lib/python3.12/site-packages (from yfinance) (6.1.3)
# Requirement already satisfied: multitasking>=0.0.7 in ./venv/lib/python3.12/site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: numpy>=1.16.5 in ./venv/lib/python3.12/site-packages (from yfinance) (2.5.3)
# Requirement already satisfied: pandas>=1.3.0 in ./venv/lib/python3.12/site-packages (from yfinance) (3.0.5)
# Requirement already satisfied: peewee>=3.16.2 in ./venv/lib/python3.12/site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: platformdirs>=2.0.0 in ./venv/lib/python3.12/site-packages (from yfinance) (4.11.8)
# Requirement already satisfied: protobuf>=3.19.0 in ./venv/lib/python3.12/site-packages (from yfinance) (7.36.1)
# Requirement already satisfied: pytz>=2022.5 in ./venv/lib/python3.12/site-packages (from yfinance) (2026.3.post1)
# Requirement already satisfied: requests>=2.31 in ./venv/lib/python3.12/site-packages (from yfinance) (2.34.2)
# Requirement already satisfied: websockets>=13.0 in ./venv/lib/python3.12/site-packages (from yfinance) (17.1)
# Requirement already satisfied: soupsieve>=1.6.1 in ./venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in ./venv/lib/python3.12/site-packages (from curl_cffi>=0.15->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2024.2.2 in ./venv/lib/python3.12/site-packages (from curl_cffi>=0.15->yfinance) (2026.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.8.0)
# Requirement already satisfied: pycparser in ./venv/lib/python3.12/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in ./venv/lib/python3.12/site-packages (3.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.12/site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in ./venv/lib/python3.12/site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.12/site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in ./venv/lib/python3.12/site-packages (from matplotlib) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.12/site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in ./venv/lib/python3.12/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance

# %%
tiker = input("Escriba el código de la acción: ")

data = yfinance.download([tiker], period="6mo")

cierre = data.Close[tiker]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
cierre.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Hacer los análisis solicitados por el gestor
#
# * Cotización máxima
# * Cotización mínima
# * Cotización media

# %%
maxima = round(cierre.max(), 2)
minima = round(cierre.min(), 2)
valor_medio = round(cierre.mean(), 2)

# %%
print(maxima)
print(minima)
print(valor_medio)
# Out:
# 339.79
# 246.19
# 296.11

# %% [markdown]
# ## Enviar correos electrónicos

# %%
# %pip install pyautogui
# %pip install pyperclip
# Out:
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.54.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 207.5 kB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python3-Xlib (from pyautogui)
#   Downloading python3-xlib-0.15.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 496.9 kB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pymsgbox (from pyautogui)
#   Downloading pymsgbox-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting pytweening>=1.0.4 (from pyautogui)
#   Downloading pytweening-1.2.0.tar.gz (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.2/171.2 kB 769.2 kB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyscreeze>=0.1.21 (from pyautogui)
#   Downloading pyscreeze-1.0.1.tar.gz (27 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pygetwindow>=0.0.5 (from pyautogui)
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mouseinfo (from pyautogui)
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyrect (from pygetwindow>=0.0.5->pyautogui)
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyperclip (from mouseinfo->pyautogui)
#   Downloading pyperclip-1.11.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading pymsgbox-2.0.1-py3-none-any.whl (10.0 kB)
# Downloading pyperclip-1.11.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, pytweening, mouseinfo, python3-Xlib, pyrect
#   Building wheel for pyautogui (pyproject.toml) ... done
#   Created wheel for pyautogui: filename=pyautogui-0.9.54-py3-none-any.whl size=37684 sha256=3c09388f8ffcb6f21c38858fc54010cf1ca684b3e45dd2d9082d92a139b6dd36
#   Stored in directory: /home/cohorte5/.cache/pip/wheels/d9/d6/47/04075995b093ecc87c212c9a3dbd34e59456c6fe504d65c3e4
#   Building wheel for pygetwindow (pyproject.toml) ... done
#   Created wheel for pygetwindow: filename=pygetwindow-0.0.9-py3-none-any.whl size=11120 sha256=e3ee296ed994216e6c1f15df21dbdcbc56b3d271163ae9652a15b5dd6e092e71
#   Stored in directory: /home/cohorte5/.cache/pip/wheels/b3/39/81/34dd7a2eca5f885f1f6e2796761970daf66a2d98ac1904f5f4
#   Building wheel for pyscreeze (pyproject.toml) ... done
#   Created wheel for pyscreeze: filename=pyscreeze-1.0.1-py3-none-any.whl size=14458 sha256=aa110c2936c436ed1c8741bee05ed506eb5fd46c77b1e24536aa8de710688281
#   Stored in directory: /home/cohorte5/.cache/pip/wheels/cd/3a/c2/7f2839239a069aa3c9564f6777cbb29d733720ef673f104f0d
#   Building wheel for pytweening (pyproject.toml) ... done
#   Created wheel for pytweening: filename=pytweening-1.2.0-py3-none-any.whl size=8113 sha256=5168bb4000a525d8ea7170d0b47670953c8b873d8a1fbd9905bcee2d6a6eaf24
#   Stored in directory: /home/cohorte5/.cache/pip/wheels/23/d5/13/4e9bdadbfe3c78e47c675e7410c0eed2fbb63c5ea6cf1b40e7
#   Building wheel for mouseinfo (pyproject.toml) ... done
#   Created wheel for mouseinfo: filename=mouseinfo-0.1.3-py3-none-any.whl size=10943 sha256=c3a6b080aa42c4a9d82698766112d5846c2c41ab142943bbf7342b908c779412
#   Stored in directory: /home/cohorte5/.cache/pip/wheels/b1/9b/f3/08650eb7f00af32f07789f3c6a101e0d7fc762b9891ae843bb
#   Building wheel for python3-Xlib (pyproject.toml) ... done
#   Created wheel for python3-Xlib: filename=python3_xlib-0.15-py3-none-any.whl size=109549 sha256=7ed6390940a83d4ca8e28df41852c9d6ede9e2accf3e89b2e085dbef4534b950
#   Stored in directory: /home/cohorte5/.cache/pip/wheels/a1/4c/74/f3627dc31a082129210025befb30084e73af761d007ac5c7b3
#   Building wheel for pyrect (pyproject.toml) ... done
#   Created wheel for pyrect: filename=pyrect-0.2.0-py2.py3-none-any.whl size=11278 sha256=a711736938dfc446acb6c1142fc987a882cfed8ae9b5593f74d6b274eceeef34
#   Stored in directory: /home/cohorte5/.cache/pip/wheels/0b/1e/d7/0c74bd8f60b39c14d84e307398786002aa7ddc905927cc03c5
# Successfully built pyautogui pygetwindow pyscreeze pytweening mouseinfo python3-Xlib pyrect
# Installing collected packages: pytweening, python3-Xlib, pyscreeze, pyrect, pyperclip, pymsgbox, pygetwindow, mouseinfo, pyautogui
# Successfully installed mouseinfo-0.1.3 pyautogui-0.9.54 pygetwindow-0.0.9 pymsgbox-2.0.1 pyperclip-1.11.0 pyrect-0.2.0 pyscreeze-1.0.1 python3-Xlib-0.15 pytweening-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyperclip in ./venv/lib/python3.12/site-packages (1.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyautogui
import pyperclip
import webbrowser

# %%
webbrowser.open("https://mail.google.com/mail/u/0/#inbox")
