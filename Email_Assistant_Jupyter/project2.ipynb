# %% [markdown]
# # Proyecto 2
#
# * Buscar datos del precio de las acciones
# * Hacer análisis solicitados por el gestor
#     * Cotización máxima
#     * Cotización mínima
#     * Valor medio
# * Enviar correo electrónico

# %% [markdown]
# ## Buscar datos del precio de las acciones

# %%
# %pip install yfinance
# %pip install matplotlib
# Out:
# Collecting yfinance
#   Using cached yfinance-1.7.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Using cached beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Using cached curl_cffi-0.16.3-cp310-abi3-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: lxml>=4.9.0 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (6.1.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (2.5.3)
# Collecting pandas>=1.3.0 (from yfinance)
#   Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (4.11.9)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (7.36.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (2026.3.post1)
# Requirement already satisfied: requests>=2.31 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (2.34.2)
# Requirement already satisfied: websockets>=13.0 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from yfinance) (17.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Collecting cffi>=2.0.0 (from curl_cffi>=0.15->yfinance)
#   Using cached cffi-2.1.1-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2026.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from requests>=2.31->yfinance) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from requests>=2.31->yfinance) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from requests>=2.31->yfinance) (2.8.0)
# Requirement already satisfied: pycparser in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Using cached yfinance-1.7.0-py3-none-any.whl (149 kB)
# Using cached beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
# Using cached curl_cffi-0.16.3-cp310-abi3-win_amd64.whl (2.0 MB)
# Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached cffi-2.1.1-cp312-cp312-win_amd64.whl (185 kB)
# Installing collected packages: cffi, beautifulsoup4, pandas, curl_cffi, yfinance
# Successfully installed beautifulsoup4-4.15.0 cffi-2.1.1 curl_cffi-0.16.3 pandas-3.0.5 yfinance-1.7.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Using cached matplotlib-3.11.2-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gustavo rodriguez\desktop\ai_dev\portfolio-ai\email_assistant_jupyter\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.11.2-cp312-cp312-win_amd64.whl (9.3 MB)
# Installing collected packages: matplotlib
# Successfully installed matplotlib-3.11.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance

# %%
tiker = input("Escriba el código de la acción: ")

data = yfinance.download([tiker], period="6mo")

cierre = data.Close[tiker]

# %%
cierre.plot()

# %% [markdown]
# ## Hacer los análisis solicitados por el gestor
#
# * Cotización máxima
# * Cotización mínima
# * Cotización media

# %%
maxima = round(cierre.max(), 2)
minima = round(cierre.min(), 2)
valor_medio = round(cierre.mean(), 2)

# %%
print(maxima)
print(minima)
print(valor_medio)

# %% [markdown]
# ## Enviar correos electrónicos

# %%
# %pip install pyautogui
# %pip install pyperclip

# %%
import pyautogui
import pyperclip
import webbrowser
import time

# %%
webbrowser.open("https://mail.google.com/mail/u/0/#inbox")

destinatario = "edig0rgudevia@gmail.com"
asunto = "Análisis acciones últimos 6 meses"
mensaje = f'''
Buenas noches Zai,

Acá te envío el análisis de las acciones de Apple de los últimos 6 meses:

Cotización máxima: USD {maxima}
Cotización mínima: USD {minima}
Valor medio: USD {valor_medio}

¡Estoy pendiente a cualquier observación!

Atentamente, 
Diego Rodríguez
'''

time.sleep(3)

pyautogui.PAUSE = 3

pyautogui.click(3774,315)

pyperclip.copy(destinatario)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("tab")

pyperclip.copy(asunto)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("tab")

pyperclip.copy(mensaje)
pyautogui.hotkey("ctrl", "v")

pyautogui.click(5195, 1460)

pyautogui.hotkey("ctrl", "w")

# %% [markdown]
# ## Ejercicio para poner coordenadas

# %%
time.sleep(3)

pyautogui.position()
